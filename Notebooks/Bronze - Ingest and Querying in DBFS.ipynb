# %% [markdown]
# # Bronze Layer: Raw Data Ingestion
#
# This notebook demonstrates the ingestion of raw data into the bronze layer of a Lakehouse architecture using Databricks, PySpark, and Delta Lake. The bronze layer stores raw, unprocessed data as Delta tables, serving as the foundation for further data cleansing and transformation.
#
# ---
#
# ## 1. Schema Creation <a name="schema-creation"></a>
#
# Create the `bronze` schema if it does not already exist.

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ## 2. Raw Data Ingestion <a name="raw-data-ingestion"></a>
#
# ### Trips Data <a name="trips-data"></a>
#
# Read the raw trips CSV file, infer the schema, and write the data as a Delta table in the bronze layer.

# %%
trips_bronze = (
    spark.read
    .format("csv")
    .option("header", "false")
    .option("inferSchema", "true")
    .load("/FileStore/tables/trips.csv")
)

trips_bronze.write.format("delta").mode("overwrite").save("/FileStore/delta/bronze/trips")

# %% [markdown]
# Register the trips Delta file as a managed table in the bronze schema.

# %%
spark.sql("""
CREATE OR REPLACE TABLE bronze.trips
USING DELTA
AS
SELECT *
FROM delta.`/FileStore/delta/bronze/trips`
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %% [markdown]
# ## 3. Data Validation <a name="data-validation"></a>
#
# Preview the ingested trips data from the bronze layer.

# %%
# %sql
SELECT *
FROM delta.`/FileStore/delta/bronze/trips`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th>_c1</th><th>_c2</th><th>_c3</th><th>_c4</th><th>_c5</th><th>_c6</th></tr></thead><tbody><tr><td>FBF3A2EEF4F9E53E</td><td>electric_bike</td><td>2021-05-26T18:57:10Z</td><td>2021-05-26T19:15:11Z</td><td>KP1705001026</td><td>13068</td><td>71614</td></tr><tr><td>96A78AE4A5072339</td><td>classic_bike</td><td>2021-05-19T20:56:26Z</td><td>2021-05-19T21:21:36Z</td><td>18003</td><td>KA1504000133</td><td>72170</td></tr><tr><td>4FC6B999FE040FF8</td><td>classic_bike</td><td>2021-05-05T09:54:09Z</td><td>2021-05-05T10:00:57Z</td><td>TA1305000002</td><td>624</td><td>42266</td></tr><tr><td>621CAA156016F645</td><td>classic_bike</td><td>2021-05-06T18:28:40Z</td><td>2021-05-06T18:32:16Z</td><td>TA1305000002</td><td>13150</td><td>38514</td></tr><tr><td>F9451546A5F9098C</td><td>docked_bike</td><td>2021-05-30T00:44:36Z</td><td>2021-05-30T01:38:24Z</td><td>15541</td><td>624</td><td>30379</td></tr><tr><td>766B3AB194E3C8F7</td><td>classic_bike</td><td>2021-05-14T19:46:27Z</td><td>2021-05-14T19:54:31Z</td><td>TA1305000002</td><td>13150</td><td>34940</td></tr><tr><td>1B266B9EBAB7BCE4</td><td>classic_bike</td><td>2021-05-20T23:28:07Z</td><td>2021-05-20T23:41:59Z</td><td>TA1307000117</td><td>13150</td><td>67177</td></tr><tr><td>67A26F701A72A0E7</td><td>electric_bike</td><td>2021-05-19T23:05:17Z</td><td>2021-05-19T23:16:06Z</td><td>TA1307000117</td><td>13150</td><td>51036</td></tr><tr><td>33330E219F91A997</td><td>classic_bike</td><td>2021-05-15T12:55:08Z</td><td>2021-05-15T13:01:54Z</td><td>TA1305000002</td><td>13150</td><td>10751</td></tr><tr><td>C2BEE53F2CC06C3B</td><td>classic_bike</td><td>2021-05-26T20:44:35Z</td><td>2021-05-26T22:09:58Z</td><td>13300</td><td>TA1307000150</td><td>49914</td></tr><tr><td>A237B0B51662581E</td><td>classic_bike</td><td>2021-05-29T19:34:45Z</td><td>2021-05-29T20:29:06Z</td><td>13300</td><td>KA1503000015</td><td>11329</td></tr><tr><td>17DF7A59B54AAF74</td><td>classic_bike</td><td>2021-05-26T20:44:18Z</td><td>2021-05-26T22:10:56Z</td><td>13300</td><td>TA1307000150</td><td>8071</td></tr><tr><td>2CA34E0C45388B47</td><td>docked_bike</td><td>2021-05-22T14:39:14Z</td><td>2021-05-22T16:18:53Z</td><td>13300</td><td>TA1307000150</td><td>44796</td></tr><tr><td>5488172AB2A0F4E1</td><td>docked_bike</td><td>2021-05-14T16:44:45Z</td><td>2021-05-14T17:18:08Z</td><td>13001</td><td>KA1503000015</td><td>40447</td></tr><tr><td>269BD30598DB4E13</td><td>classic_bike</td><td>2021-05-14T13:29:37Z</td><td>2021-05-14T13:40:59Z</td><td>TA1307000115</td><td>KA1504000133</td><td>38864</td></tr><tr><td>CF59A4B27C425C20</td><td>docked_bike</td><td>2021-05-15T17:13:21Z</td><td>2021-05-15T17:36:38Z</td><td>13036</td><td>KA1504000133</td><td>22468</td></tr><tr><td>0A6DE75AC2010894</td><td>docked_bike</td><td>2021-05-16T16:29:02Z</td><td>2021-05-16T17:40:09Z</td><td>KA1503000064</td><td>KA1504000133</td><td>75467</td></tr><tr><td>70AF4F0B12795560</td><td>classic_bike</td><td>2021-05-22T10:05:37Z</td><td>2021-05-22T10:09:07Z</td><td>TA1307000126</td><td>TA1307000150</td><td>34007</td></tr><tr><td>38B23BA5DAE06FB7</td><td>classic_bike</td><td>2021-05-03T16:15:27Z</td><td>2021-05-03T16:21:08Z</td><td>TA1307000126</td><td>TA1307000150</td><td>33395</td></tr><tr><td>769CF8EC63DD066E</td><td>electric_bike</td><td>2021-05-10T15:28:23Z</td><td>2021-05-10T15:37:25Z</td><td>13229</td><td>TA1307000150</td><td>24843</td></tr><tr><td>CADC02B37011E01F</td><td>classic_bike</td><td>2021-05-22T22:25:18Z</td><td>2021-05-22T23:49:16Z</td><td>13036</td><td>KA1503000015</td><td>71854</td></tr><tr><td>794143FEEB1C0AD8</td><td>electric_bike</td><td>2021-05-17T18:46:35Z</td><td>2021-05-17T18:56:17Z</td><td>TA1307000052</td><td>TA1307000150</td><td>38174</td></tr><tr><td>114DDC74C02641EF</td><td>classic_bike</td><td>2021-05-03T14:20:03Z</td><td>2021-05-03T14:27:55Z</td><td>TA1307000052</td><td>TA1307000150</td><td>24945</td></tr><tr><td>64BF23067500B564</ ...

# %% [markdown]
# ### Riders Data <a name="riders-data"></a>
#
# Read the raw riders CSV file, infer the schema, and write the data as a Delta table in the bronze layer.

# %%
riders_bronze = (
    spark.read
    .format("csv")
    .option("header", "false")
    .option("inferSchema", "true")
    .load("/FileStore/tables/riders.csv")
)

riders_bronze.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/FileStore/delta/bronze/riders")

# %% [markdown]
# Register the riders Delta file as a managed table in the bronze schema.

# %%
spark.sql("""
CREATE OR REPLACE TABLE bronze.riders
USING DELTA
AS
SELECT *
FROM delta.`/FileStore/delta/bronze/riders`
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %% [markdown]
# Display metadata and schema information for the `bronze.riders` table to validate the ingestion and structure of the raw riders data.

# %%
spark.sql("DESCRIBE DETAIL bronze.riders").show(truncate=False)
spark.table("bronze.riders").printSchema()
# Out:
# +------+------------------------------------+---------------------------+-----------+------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |format|id                                  |name                       |description|location                                  |createdAt              |lastModified       |partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties                           |minReaderVersion|minWriterVersion|tableFeatures                            |statistics                                                     |clusterByAuto|
# +------+------------------------------------+---------------------------+-----------+------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |delta |12183d9f-a909-4680-bc34-06b4cf2079ee|spark_catalog.bronze.riders|NULL       |dbfs:/user/hive/warehouse/bronze.db/riders|2026-04-16 23:12:22.898|2026-04-16 23:12:23|[]              |[]               |6       |2347149    |{delta.enableDeletionVectors -> true}|3               |7               |[appendOnly, deletionVectors, invariants]|{numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0}|false        |
# +------+------------------------------------+---------------------------+-----------+------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
#
# root
#  |-- _c0: integer (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: date (nullable = true)
#  |-- _c5: date (nullable = true)
#  |-- _c6: date (nullable = true)
#  |-- _c7: boolean (nullable = true)

# %% [markdown]
# ---
#
# ### Stations Data <a name="stations-data"></a>
#
# Read the raw stations CSV file, infer the schema, and write the data as a Delta table in the bronze layer.

# %%
stations_bronze = (
    spark.read
    .format("csv")
    .option("header", "false")
    .option("inferSchema", "true")
    .load("/FileStore/tables/stations.csv")
)

stations_bronze.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/FileStore/delta/bronze/stations")

# %% [markdown]
# Register the stations Delta file as a managed table in the bronze schema.

# %%
spark.sql("""
CREATE OR REPLACE TABLE bronze.stations
USING DELTA
AS
SELECT *
FROM delta.`/FileStore/delta/bronze/stations`
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %% [markdown]
# Display metadata and schema information for the `bronze.stations` table to validate the ingestion and structure of the raw stations data.

# %%
spark.sql("DESCRIBE DETAIL bronze.stations").show(truncate=False)
spark.table("bronze.stations").printSchema()
# Out:
# +------+------------------------------------+-----------------------------+-----------+--------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |format|id                                  |name                         |description|location                                    |createdAt              |lastModified       |partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties                           |minReaderVersion|minWriterVersion|tableFeatures                            |statistics                                                     |clusterByAuto|
# +------+------------------------------------+-----------------------------+-----------+--------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |delta |eb4d7768-13a2-4ff0-acda-09c99a68402a|spark_catalog.bronze.stations|NULL       |dbfs:/user/hive/warehouse/bronze.db/stations|2026-04-16 23:12:50.147|2026-04-16 23:12:51|[]              |[]               |1       |28730      |{delta.enableDeletionVectors -> true}|3               |7               |[appendOnly, deletionVectors, invariants]|{numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0}|false        |
# +------+------------------------------------+-----------------------------+-----------+--------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
#
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: double (nullable = true)
#  |-- _c3: double (nullable = true)

# %% [markdown]
# ---
#
# ### Payments Data <a name="payments-data"></a>
#
# Read the raw payments CSV file, infer the schema, and write the data as a Delta table in the bronze layer.

# %%
payments_bronze = (
    spark.read
    .format("csv")
    .option("header", "false")
    .option("inferSchema", "true")
    .load("/FileStore/tables/payments.csv")
)

payments_bronze.write \
    .format("delta") \
    .mode("overwrite") \
    .save("/FileStore/delta/bronze/payments")

# %% [markdown]
# Register the payments Delta file as a managed table in the bronze schema.

# %%
spark.sql("""
CREATE OR REPLACE TABLE bronze.payments
USING DELTA
AS
SELECT *
FROM delta.`/FileStore/delta/bronze/payments`
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]

# %%
spark.sql("DESCRIBE DETAIL bronze.payments").show(truncate=False)
spark.table("bronze.payments").printSchema()
# Out:
# +------+------------------------------------+-----------------------------+-----------+--------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |format|id                                  |name                         |description|location                                    |createdAt              |lastModified       |partitionColumns|clusteringColumns|numFiles|sizeInBytes|properties                           |minReaderVersion|minWriterVersion|tableFeatures                            |statistics                                                     |clusterByAuto|
# +------+------------------------------------+-----------------------------+-----------+--------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
# |delta |3567e659-577c-4382-9c2f-8b6f5a542c5d|spark_catalog.bronze.payments|NULL       |dbfs:/user/hive/warehouse/bronze.db/payments|2026-04-16 23:23:32.321|2026-04-16 23:23:33|[]              |[]               |8       |9559652    |{delta.enableDeletionVectors -> true}|3               |7               |[appendOnly, deletionVectors, invariants]|{numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0}|false        |
# +------+------------------------------------+-----------------------------+-----------+--------------------------------------------+-----------------------+-------------------+----------------+-----------------+--------+-----------+-------------------------------------+----------------+----------------+-----------------------------------------+---------------------------------------------------------------+-------------+
#
# root
#  |-- _c0: integer (nullable = true)
#  |-- _c1: date (nullable = true)
#  |-- _c2: double (nullable = true)
#  |-- _c3: integer (nullable = true)

# %% [markdown]
# ---
#
# ## Conclusion
#
# All raw data sources have been ingested into the bronze layer as Delta tables. These tables provide a reliable foundation for further data processing and transformation in the Lakehouse architecture.
